# %% [markdown]
# # **Python Para Análise de dados** - *João Pedro R. Baraúna*

# %% [markdown]
# # **Estrutura de dados**

# %% [markdown]
# ## **Listas**

# %%
#Criando uma lista >> animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ['cão', 'gato', 'peixe', 'urso', 'tubarão', 1, 2.3]
animais
# Out:
# ['cão', 'gato', 'peixe', 'urso', 'tubarão', 1, 2.3]

# %%
#primeiro elemento da lista
animais[0]
# Out:
# 'cão'

# %%
#2° elemento da lista
animais[1]
# Out:
# 'gato'

# %%
#Substituindo o 3° elemento da lista
animais[2] = "papagaio"

# %%
animais
# Out:
# ['cão', 'gato', 'papagaio', 'urso', 'tubarão', 1, 2.3]

# %%
#Removendo [papagaio] da lista
animais.remove('papagaio')

# %%
animais
# Out:
# ['cão', 'gato', 'urso', 'tubarão', 1, 2.3]

# %%
len(animais)
# Out:
# 6

# %%
"papagaio" in animais
# Out:
# False

# %%
lista = [300, 301, 700, 90, 20]

# %%
max(lista)
# Out:
# 700

# %%
min(lista)
# Out:
# 20

# %%
animais.append(['touro', 'salmão'])

# %%
animais
# Out:
# ['cão', 'gato', 'urso', 'tubarão', 1, 2.3, ['touro', 'salmão']]

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['cão', 'gato', 'urso', 'tubarão', 1, 2.3, ['touro', 'salmão'], 'cobra', 6]

# %%
animais.count("leão")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [20, 90, 300, 301, 700]

# %% [markdown]
# # **Tuplas**

# %%
#As tuplas usam parênteses como sintaxe
tp = ('uva', 'manga', 20, 90)

# %%
#primeiro elemento
tp[0]
# Out:
# 'uva'

# %%
#Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9264cd18bf8a> in <module>()
#       1 #Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count('uva')
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('uva', 'manga')

# %% [markdown]
# # **Dicionários**

# %%
#Para criar um dicionário utilizamos as {}
dc = {'Pera':12, 'Banana':23, 'Limao':43, 'Pessego':45} #Dicionários trabalham com o conceito chave e valor

# %%
dc
# Out:
# {'Banana': 23, 'Limao': 43, 'Pera': 12, 'Pessego': 45}

# %%
#Acessando o valor de um dicionário através da chave
dc['Pera']
# Out:
# 12

# %%
#Atualizando o valor da Maçã
dc['Pera'] = 25
dc
# Out:
# {'Banana': 23, 'Limao': 43, 'Pera': 25, 'Pessego': 45}

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Pera', 'Banana', 'Limao', 'Pessego'])

# %%
#Retornando os valores do dicionário
dc.values()
# Out:
# dict_values([25, 23, 43, 45])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault('Uva', 15)
# Out:
# 15

# %%
dc
# Out:
# {'Banana': 23, 'Limao': 43, 'Pera': 25, 'Pessego': 45, 'Uva': 15}
