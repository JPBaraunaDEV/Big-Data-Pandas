# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Aprendendo Python")
# Out:
# Aprendendo Python

# %%
"Python"
# Out:
# 'Python'

# %%
3 + 16
# Out:
# 19

# %%
10 - 5
# Out:
# 5

# %%
#Comentário

# %%
#Multiplicação
2 * 10
# Out:
# 20

# %%
#Divisão
10/5
# Out:
# 2.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
#Criando uma variável STRING
frase = 'Python for data analysis'

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python for'

# %%
frase[10:]
# Out:
# ' data analysis'

# %%
frase[:17]
# Out:
# 'Python for data a'

# %%
frase.count('data')
# Out:
# 0

# %%
frase.lower()
# Out:
# 'python for data analysis'

# %%
frase = frase.upper()

# %%
frase.replace("PYTHON","SCALA")
# Out:
# 'SCALA FOR DATA ANALYSIS'

# %%
frase
# Out:
# 'PYTHON FOR DATA ANALYSIS'
